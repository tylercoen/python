# %%
# CARD
# SUIT,RANK,VALUE
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
class Deck:
    
    def __init__(self):
        self.all_cards = []
        
        for suit in suits:
            for rank in ranks:
                #Create the card object
                created_card = Card(suit,rank)
                self.all_cards.append(created_card)
                
    def shuffle(self):
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()

# %%
new_deck = Deck()

# %%
new_deck.shuffle()

# %%
mycard = new_deck.deal_one()

# %%
print(mycard)
# Out:
# King of Spades

# %%
len(new_deck.all_cards)
# Out:
# 51

# %%
class Player:
    
    def __init__(self,name):
        self.name = name
        self.all_cards = []
        
    def remove_one(self):
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            # list of multiple Card objects
            self.all_cards.extend(new_cards)
        else:
            # Fora  single card object
            self.all_cards.append(new_cards)
    
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards.'

# %%
new_player = Player("Tyler")

# %%
print(new_player.name)
# Out:
# Tyler

# %%
new_player.add_cards(mycard)

# %%
print(new_player)
# Out:
# Player Tyler has 1 cards.

# %%
print(new_player.all_cards[0])
# Out:
# King of Spades

# %%
new_player.add_cards([mycard,mycard,mycard])

# %%
print(new_player)
# Out:
# Player Tyler has 4 cards.

# %%
new_player.remove_one()

# %%
print(new_player)
# Out:
# Player Tyler has 3 cards.

# %%
# GAME SETUP
player_one = Player('Ash')
player_two = Player('Sasha')

new_deck = Deck()
new_deck.shuffle()

for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
len(player_one.all_cards)
# Out:
# 26

# %%
game_on = True

# %%
round_num = 0

while game_on:
    
    round_num += 1
    print(f"Rounds {round_num}")
    
    if len(player_one.all_cards) == 0:
        print(f"{player_one.name}, out of cards! {player_two.name} wins!")
        game_on = False
        break
        
    if len(player_two.all_cards) == 0:
        print(f"{player_two.name}, out of cards! {player_one.name} wins!")
        game_on = False
        break
        
    # START A NEW ROUND
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    at_war = True
    
    while at_war:
        
        if player_one_cards[-1].value > player_two_cards[-1].value:
            
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            
            at_war = False
            
        elif player_one_cards[-1].value < player_two_cards[-1].value:
            
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            
            at_war = False
            
        else:
            print("WAR!")
            
            if len(player_one.all_cards) < 5:
                print(f"{player_one.name} cannot declare war, not enough cards")
                print(f"{player_two.name} wins")
                game_on = False
                break
            elif len(player_two.all_cards) < 5:
                print(f"{player_two.name} cannot declare war, not enough cards")
                print(f"{player_one.name} wins")
                game_on = False
                break
                
            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Rounds 1
# Rounds 2
# Rounds 3
# Rounds 4
# Rounds 5
# Rounds 6
# Rounds 7
# Rounds 8
# Rounds 9
# Rounds 10
# Rounds 11
# WAR!
# Rounds 12
# Rounds 13
# Rounds 14
# WAR!
# Rounds 15
# Rounds 16
# Rounds 17
# Rounds 18
# Rounds 19
# Rounds 20
# Rounds 21
# Rounds 22
# WAR!
# Rounds 23
# Rounds 24
# Rounds 25
# Rounds 26
# Rounds 27
# Rounds 28
# Rounds 29
# Rounds 30
# Rounds 31
# Rounds 32
# Rounds 33
# Rounds 34
# Rounds 35
# Rounds 36
# Rounds 37
# Rounds 38
# Rounds 39
# Rounds 40
# Rounds 41
# WAR!
# Rounds 42
# Rounds 43
# Rounds 44
# Rounds 45
# Rounds 46
# Rounds 47
# Rounds 48
# WAR!
# Rounds 49
# Rounds 50
# Rounds 51
# Rounds 52
# Rounds 53
# Rounds 54
# Rounds 55
# Rounds 56
# Rounds 57
# Rounds 58
# Rounds 59
# Rounds 60
# Rounds 61
# Rounds 62
# Rounds 63
# Rounds 64
# Rounds 65
# Rounds 66
# Rounds 67
# Rounds 68
# Rounds 69
# Rounds 70
# Rounds 71
# Rounds 72
# WAR!
# Rounds 73
# Rounds 74
# Rounds 75
# Rounds 76
# Rounds 77
# Rounds 78
# Rounds 79
# Rounds 80
# Rounds 81
# Rounds 82
# Rounds 83
# Rounds 84
# Rounds 85
# Rounds 86
# Rounds 87
# Rounds 88
# Rounds 89
# Rounds 90
# Rounds 91
# Rounds 92
# Rounds 93
# Rounds 94
# Rounds 95
# Rounds 96
# Rounds 97
# Rounds 98
# Rounds 99
# Rounds 100
# Rounds 101
# Rounds 102
# Rounds 103
# Rounds 104
# Rounds 105
# Rounds 106
# Rounds 107
# Rounds 108
# Rounds 109
# Rounds 110
# Rounds 111
# Rounds 112
# Rounds 113
# Rounds 114
# Rounds 115
# Rounds 116
# Rounds 117
# Rounds 118
# Rounds 119
# Rounds 120
# WAR!
# Rounds 121
# Rounds 122
# WAR!
# Rounds 123
# Rounds 124
# Rounds 125
# Rounds 126
# Rounds 127
# Rounds 128
# Rounds 129
# Rounds 130
# Rounds 131
# Rounds 132
# WAR!
# Rounds 133
# WAR!
# Rounds 134
# Rounds 135
# Rounds 136
# Rounds 137
# Rounds 138
# Rounds 139
# Rounds 140
# Rounds 141
# Rounds 142
# Rounds 143
# Rounds 144
# Rounds 145
# Rounds 146
# Rounds 147
# Rounds 148
# Rounds 149
# Rounds 150
# Rounds 151
# Rounds 152
# Rounds 153
# Rounds 154
# Rounds 155
# Rounds 156
# Rounds 157
# Rounds 158
# Rounds 159
# Rounds 160
# Rounds 161
# Rounds 162
# Rounds 163
# WAR!
# Rounds 164
# Rounds 165
# Rounds 166
# Rounds 167
# Rounds 168
# Rounds 169
# Rounds 170
# Rounds 171
# Rounds 172
# Rounds 173
# Rounds 174
# WAR!
# Rounds 175
# Rounds 176
# Rounds 177
# Rounds 178
# Rounds 179
# Rounds 180
# Rounds 181
# Rounds 182
# Rounds 183
# WAR!
# Rounds 184
# Rounds 185
# Rounds 186
# Rounds 187
# WAR!
# Rounds 188
# Rounds 189
# WAR!
# WAR!
# Rounds 190
# Rounds 191
# Rounds 192
# Rounds 193
# Rounds 194
# Rounds 195
# Rounds 196
# Rounds 197
# Rounds 198
# Rounds 199
# Rounds 200
# Rounds 201
# Rounds 202
# Rounds 203
# Rounds 204
# Rounds 205
# Rounds 206
# Rounds 207
# Rounds 208
# Rounds 209
# Rounds 210
# Rounds 211
# Rounds 212
# Rounds 213
# Rounds 214
# Rounds 215
# Rounds 216
# Rounds 217
# WAR!
# Rounds 218
# Rounds 219
# Rounds 220
# Rounds 221
# Rounds 222
# Rounds 223
# Rounds 224
# Rounds 225
# Rounds 226
# Rounds 227
# Rounds 228
# Rounds 229
# Rounds 230
# WAR!
# Rounds 231
# Rounds 232
# Rounds 233
# Rounds 234
# Rounds 235
# Rounds 236
# Rounds 237
# Rounds 238
# Rounds 239
# Rounds 240
# Rounds 241
# WAR!
# Rounds 242
# WAR!
# Rounds 243
# Rounds 244
# Rounds 245
# Rounds 246
# Rounds 247
# Rounds 248
# Rounds 249
# Rounds 250
# Rounds 251
# Rounds 252
# Rounds 253
# Rounds 254
# Rounds 255
# Rounds 256
# Rounds 257
# Rounds 258
# Rounds 259
# Rounds 260
# Rounds 261
# Rounds 262
# Rounds 263
# Rounds 264
# Rounds 265
# Rounds 266
# Rounds 267
# Rounds 268
# Rounds 269
# Rounds 270
# Rounds 271
# Rounds 272
# Rounds 273
# Rounds 274
# Rounds 275
# Rounds 276
# Rounds 277
# Rounds 278
# Rounds 279
# Rounds 280
# Rounds 281
# Rounds 282
# Rounds 283
# Rounds 284
# Rounds 285
# Rounds 286
# Rounds 287
# Rounds 288
# Rounds 289
# Rounds 290
# WAR!
# Rounds 291
# Rounds 292
# Rounds 293
# Rounds 294
# Rounds 295
# Rounds 296
# Rounds 297
# Rounds 298
# Rounds 299
# Rounds 300
# Rounds 301
# Rounds 302
# Rounds 303
# Rounds 304
# Rounds 305
# Rounds 306
# Rounds 307
# Rounds 308
# Rounds 309
# Rounds 310
# Rounds 311
# Rounds 312
# Rounds 313
# Rounds 314
# Rounds 315
# Rounds 316
# Rounds 317
# Rounds 318
# Rounds 319
# Rounds 320
# Rounds 321
# Rounds 322
# Rounds 323
# Rounds 324
# WAR!
# Rounds 325
# Rounds 326
# WAR!
# Rounds 327
# Rounds 328
# Rounds 329
# Rounds 330
# Rounds 331
# Rounds 332
# Rounds 333
# Rounds 334
# Rounds 335
# Rounds 336
# Rounds 337
# Rounds 338
# Rounds 339
# Rounds 340
# WAR!
# Rounds 341
# Rounds 342
# Rounds 343
# Rounds 344
# Rounds 345
# Rounds 346
# Rounds 347
# Rounds 348
# Rounds 349
# Rounds 350
# Rounds 351
# Rounds 352
# Rounds 353
# Rounds 354
# Rounds 355
# Rounds 356
# Rounds 357
# Rounds 358
# Rounds 359
# WAR!
# Rounds 360
# Rounds 361
# WAR!
# Rounds 362
# Rounds 363
# Rounds 364
# Rounds 365
# Rounds 366
# Rounds 367
# Rounds 368
# Rounds 369
# Rounds 370
# Rounds 371
# Rounds 372
# Rounds 373
# Rounds 374
# Rounds 375
# Rounds 376
# Rounds 377
# Rounds 378
# Rounds 379
# WAR!
# Rounds 380
# Rounds 381
# Rounds 382
# Rounds 383
# Rounds 384
# Rounds 385
# Rounds 386
# Rounds 387
# Rounds 388
# Rounds 389
# Rounds 390
# Rounds 391
# Rounds 392
# Rounds 393
# Rounds 394
# Rounds 395
# Rounds 396
# Rounds 397
# WAR!
# Rounds 398
# Rounds 399
# Rounds 400
# Rounds 401
# Rounds 402
# Rounds 403
# Rounds 404
# Rounds 405
# Rounds 406
# Rounds 407
# Rounds 408
# Rounds 409
# Rounds 410
# Rounds 411
# Rounds 412
# Rounds 413
# Rounds 414
# Rounds 415
# Rounds 416
# Rounds 417
# Rounds 418
# Rounds 419
# Rounds 420
# WAR!
# Rounds 421
# Rounds 422
# Rounds 423
# Rounds 424
# Rounds 425
# Rounds 426
# Rounds 427
# Rounds 428
# Rounds 429
# Rounds 430
# Rounds 431
# Rounds 432
# Rounds 433
# Rounds 434
# Rounds 435
# Rounds 436
# Rounds 437
# Rounds 438
# Rounds 439
# Rounds 440
# Rounds 441
# Rounds 442
# Rounds 443
# Rounds 444
# Rounds 445
# Rounds 446
# Rounds 447
# Rounds 448
# Rounds 449
# Rounds 450
# Rounds 451
# Rounds 452
# Rounds 453
# Rounds 454
# Rounds 455
# Rounds 456
# Rounds 457
# Rounds 458
# Rounds 459
# Rounds 460
# Rounds 461
# Rounds 462
# Rounds 463
# WAR!
# Sasha cannot declare war, not enough cards
# Ash wins
