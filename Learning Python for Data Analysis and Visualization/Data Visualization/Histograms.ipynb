# %%
# standard imports
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
# Stats
from scipy import stats

# %%
# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 5.,  4., 12., 20., 16., 15., 15.,  7.,  4.,  2.]),
#  array([-2.46979698, -1.95090604, -1.4320151 , -0.91312416, -0.39423322,
#          0.12465772,  0.64354866,  1.1624396 ,  1.68133054,  2.20022149,
#          2.71911243]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)

plt.hist(dataset2,color='indianred')
# Out:
# (array([ 2.,  6.,  9., 10., 10., 14., 12.,  9.,  5.,  3.]),
#  array([-2.22812355, -1.79891666, -1.36970978, -0.94050289, -0.511296  ,
#         -0.08208912,  0.34711777,  0.77632466,  1.20553154,  1.63473843,
#          2.06394532]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1,density=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)

# normed is now density.
# Out:
# (array([0.11649394, 0.        , 0.29123484, 0.05824697, 0.23298787,
#         0.29123484, 0.29123484, 0.29123484, 0.11649394, 0.46597575,
#         0.23298787, 0.58246968, 0.40772878, 0.29123484, 0.34948181,
#         0.17474091, 0.11649394, 0.17474091, 0.11649394, 0.05824697]),
#  array([-2.22812355, -2.01352011, -1.79891666, -1.58431322, -1.36970978,
#         -1.15510633, -0.94050289, -0.72589945, -0.511296  , -0.29669256,
#         -0.08208912,  0.13251433,  0.34711777,  0.56172121,  0.77632466,
#          0.9909281 ,  1.20553154,  1.42013499,  1.63473843,  1.84934187,
#          2.06394532]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
df = pd.DataFrame({'data1':data1,'data2':data2})
sns.jointplot(data=df,x='data1',y='data2')

# %%
sns.jointplot(data=df,x='data1',y='data2',kind='hex')
